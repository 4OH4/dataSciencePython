# %% [markdown]
# # Elasticsearch Basics
# Rupert Thomas, October 2020
#
# Using: https://www.elastic.co/blog/a-practical-introduction-to-elasticsearch

# %%
import requests
import json
from pprint import pprint

# %%
es_base_url = "http://elasticsearch:9200/"

# %% [markdown]
# ### Add new record, automatically create an index

# %%
# Add new record, automatically create an index

payload = {
    "name": "John",
    "lastname": "Doe",
    "job_description": "admin"
}

payload = json.dumps(payload)

headers = {
        'Content-Type': "application/json",
        'cache-control': "no-cache"
    }

url = es_base_url + "accounts/person/1"


response = requests.request("PUT", url, data=payload, headers=headers)
print(response)

json_response = json.loads(response.text)
pprint(json_response)
# Out:
# <Response [200]>
# {'_id': '1',
#  '_index': 'accounts',
#  '_primary_term': 1,
#  '_seq_no': 2,
#  '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#  '_type': 'person',
#  '_version': 3,
#  'result': 'updated'}

# %% [markdown]
# ### Get record back

# %%
# Get record back
url = es_base_url + "accounts/person/1"

response = requests.request("GET", url, data="")
print(response)

json_response = json.loads(response.text)
pprint(json_response)
# Out:
# <Response [200]>
# {'_id': '1',
#  '_index': 'accounts',
#  '_primary_term': 1,
#  '_seq_no': 2,
#  '_source': {'job_description': 'admin', 'lastname': 'Doe', 'name': 'John'},
#  '_type': 'person',
#  '_version': 3,
#  'found': True}

# %% [markdown]
# ### Update record

# %%
# Update record

payload = {
    "doc": {"job_description": "Systems admin"}
}

payload = json.dumps(payload)

headers = {
        'Content-Type': "application/json",
        'cache-control': "no-cache"
    }

url = es_base_url + "accounts/person/1/_update"


response = requests.request("POST", url, data=payload, headers=headers)
print(response)

json_response = json.loads(response.text)
pprint(json_response)
# Out:
# <Response [200]>
# {'_id': '1',
#  '_index': 'accounts',
#  '_primary_term': 1,
#  '_seq_no': 3,
#  '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#  '_type': 'person',
#  '_version': 4,
#  'result': 'updated'}

# %%
url = es_base_url + "accounts/person/1"
response = requests.request("GET", url, data="")
print(response)

json_response = json.loads(response.text)
pprint(json_response)
# Out:
# <Response [200]>
# {'_id': '1',
#  '_index': 'accounts',
#  '_primary_term': 1,
#  '_seq_no': 3,
#  '_source': {'job_description': 'Systems admin',
#              'lastname': 'Doe',
#              'name': 'John'},
#  '_type': 'person',
#  '_version': 4,
#  'found': True}

# %% [markdown]
# ### Add another document

# %%
# Add another document

payload = {
    "name": "John",
    "lastname": "Smith",
    "job_description": "Linux specialist"
}

payload = json.dumps(payload)

headers = {
        'Content-Type': "application/json",
        'cache-control': "no-cache"
    }

url = es_base_url + "accounts/person/2"


response = requests.request("PUT", url, data=payload, headers=headers)
print(response)

json_response = json.loads(response.text)
pprint(json_response)
# Out:
# <Response [201]>
# {'_id': '2',
#  '_index': 'accounts',
#  '_primary_term': 1,
#  '_seq_no': 4,
#  '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#  '_type': 'person',
#  '_version': 1,
#  'result': 'created'}

# %% [markdown]
# ## Query records
# ### Broad search

# %%
# Query records - broadly
url = es_base_url + "_search?q=john%20linux"
# url = es_base_url + "_search?q=potato"

response = requests.request("GET", url, data="")
response = json.loads(response.text)

pprint(response)
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 8, 'total': 8},
#  'hits': {'hits': [{'_id': 'Wo36jnUBztxdYHj6w_99',
#                     '_index': 'kibana_sample_data_logs',
#                     '_score': 1.9655675,
#                     '_source': {'agent': 'Mozilla/5.0 (X11; Linux x86_64; '
#                                          'rv:6.0a1) Gecko/20110421 '
#                                          'Firefox/6.0a1',
#                                 'bytes': 8489,
#                                 'clientip': '159.64.35.129',
#                                 'extension': 'gz',
#                                 'geo': {'coordinates': {'lat': 28.03925,
#                                                         'lon': -97.54244444},
#                                         'dest': 'BG',
#                                         'src': 'ET',
#                                         'srcdest': 'ET:BG'},
#                                 'host': 'artifacts.elastic.co',
#                                 'index': 'kibana_sample_data_logs',
#                                 'ip': '159.64.35.129',
#                                 'machine': {'os': 'win xp', 'ram': 16106127360},
#                                 'memory': None,
#                                 'message': '159.64.35.129 - - '
#                                            '[2018-07-22T06:06:42.742Z] "GET '
#                                            '/kibana/kibana-6.3.2-linux-x86_64.tar.gz_1 '
#                                            'HTTP/1.1" 200 8489 "-" '
#                                            '"Mozilla/5.0 (X11; Linux x86_64; '
#                                            'rv:6.0a1) Gecko/20110421 '
#                                            'Firefox/6.0a1"',
#                                 'phpmemory': None,
#                                 'referer': 'http://www.elastic-elastic-elastic.com/success/frederick-w-leslie',
#                                 'request': '/kibana/kibana-6.3.2-linux-x86_64.tar.gz',
#                                 'response': 200,
#                                 'tags': ['success', 'info'],
#                                 'timestamp': '2020-10-25T06:06:42.742Z',
#                                 'url': 'https://artifacts.elastic.co/downloads/kibana/kibana-6.3.2-linux-x86_64.tar.gz_1',
#                                 'utc_time': '2020-10-25T06:06:42.742Z'},
#                     '_type': '_doc'},
#                    {'_id': 'YI36jnUBztxdYHj6w_99',
#                     '_index': 'kibana_sample_data_logs',
#                     '_score': 1.9655675,
#                     '_source': {'agent': 'Mozilla/5.0 (X11; Linux i686) '
#                                          'AppleWebKit/534.24 (KHTML, like '
#                                          'Gecko) Chrome/11.0.696.50 '
#                                          'Safari/534.24',
#                                 'bytes': 9890,
#                                 'clientip': '117.165.135.88',
#                                 'extension': 'gz',
#                                 'geo': {'coordinates': {'lat': 39.58316583,
#                                                         'lon': -85.80481},
#                                         'dest': 'TW',
#                                         'src': 'CN',
#                                         'srcdest': 'CN:TW'},
#                                 'host': 'artifacts.elastic.co',
#                                 'index': 'kibana_sample_data_logs',
#                                 'ip': '117.165.135.88',
#                                 'machine': {'os': 'win 8', 'ram': 17179869184},
#                                 'memory': None,
#                                 'message': '117.165.135.88 - - '
#                                            '[2018-07-22T06:22:55.923Z] "GET '
#                                            '/kibana/kibana-6.3.2-linux-x86_64.tar.gz_1 '
#                                            'HTTP/1.1" 404 9890 "-" '
#                                            '"Mozilla/5.0 (X11; Linux i686) '
#                                            'AppleWebKit/534.24 (KHTML, like '
#                                            'Gecko) Chrome/11.0.696.50 '
#                                            'Safari/534.24"',
#                                 'phpmemory': None,
#                                 'referer': 'http://twitter.com/success/patrick-baudry',
#                                 'request': '/kibana/kibana-6.3.2-linux-x86_64.tar.gz',
#                                 'response': 404,
#                                 'tags': ['success', 'info'],
#                                 'timestamp': '2020-10-25T06:22:55.923Z',
#                                 'url': 'https://artifacts.elastic.co/downloads/kibana/kibana-6.3.2-linux-x86_64.tar.gz_1',
#                                 'utc_time': '2020-10-25T06:22:55.923Z'},
#                     '_type': '_doc'},
#                    {'_id': 'a436jnUBztxdYHj6w_99',
#                     '_index': 'kibana_sample_data_logs',
#                     '_score': 1.9655675,
#                     '_source': {'agent': 'Mozilla/5.0 (X11; Linux x86_64; '
#                                          'rv:6.0a1) Gecko/20110421 '
#                                          'Firefox/6.0a1',
#                                 'bytes': 8489,
#                                 'clientip': '159.64.35.129',
#                                 'extension': 'gz',
#                                 'geo': {'coordinates': {'lat': 28.03925,
#                                                         'lon': -97.54244444},
#                                         'dest': 'BG',
#                                         'src': 'ET',
#                                         'srcdest': 'ET:BG'},
#                                 'host': 'artifacts.elastic.co',
#                                 'index': 'kibana_sample_data_logs',
#                                 'ip': '159.64.35.129',
#                                 'machine': {'os': 'win xp', 'ram': 16106127360},
#                                 'memory': None,
#                                 'message': '159.64.35.129 - - '
#                                            '[2018-07-22T06:06:42.742Z] "GET '
#                                            '/kibana/kibana-6.3.2-linux-x86_64.tar.gz '
#                                            'HTTP/1.1" 200 8489 "-" '
#                                            '"Mozilla/5.0 (X11; Linux x86_64; '
#                                            'rv:6.0a1) Gecko/20110421 '
#                                            'Firefox/6.0a1"',
#                                 'phpmemory': None,
#                                 'referer': 'http://www.elastic-elastic-elastic.com/success/frederick-w-leslie',
#                                 'request': '/kibana/kibana-6.3.2-linux-x86_64.tar.gz',
#                                 'response': 200,
#                                 'tags': ['success', 'info'],
#                                 'timestamp': '2020-10-25T06:06:42.742Z',
#                                 'url': 'https://artifacts.elastic.co/downloads/kibana/kibana-6.3.2-linux-x86_64.tar.gz',
#                                 'utc_time': '2020-10-25T06:06:42.742Z'},
#                     '_type': '_doc'},
#                    {'_id': 'q436jnUBztxdYHj6w_99',
#                     '_index': 'kibana_sample_data_logs',
#                     '_score': 1.9655675,
#                     '_source': {'agent': 'Mozilla/5.0 (X11; Linux i686) '
#                                          'AppleWebKit/534.24 (KHTML, like '
#                                          'Gecko) Chrome/11.0.696.50 '
#                                          'Safari/534.24',
#                                 'bytes': 17598,
#                                 'clientip': '88.240.148.180',
#                                 'extension': 'gz',
#                                 'geo': {'coordinates': {'lat': 39.84348556,
#                                                         'lon': -85.89706389},
#                                         'dest': 'SD',
#                                         'src': 'US',
#                                         'srcdest': 'US:SD'},
#                                 'host': 'artifacts.elastic.co',
#                                 'index': 'kibana_sample_data_logs',
#                                 'ip': '88.240.148.180',
#                                 'machine': {'os': 'osx', 'ram': 6442450944},
#                                 'memory': None,
#                                 'message': '88.240.148.180 - - '
#                                            '[2018-07-22T14:00:20.549Z] "GET '
#                                            '/kibana/kibana-6.3.2-linux-x86_64.tar.gz '
#                                            'HTTP/1.1" 200 17598 "-" '
#                                            '"Mozilla/5.0 (X11; Linux i686) '
#                                            'AppleWebKit/534.24 (KHTML, like '
#                                            'Gecko) Chrome/11.0.696.50 '
#                                            'Safari/534.24"',
#                                 'phpmemory': None,
#                                 'referer': 'http://twitter.com/success/takao-doi',
#                                 'request': '/kibana/kibana-6.3.2-linux-x86_64.tar.gz',
#                                 'response': 200,
#                                 'tags': ['success', 'info'],
#                                 'timestamp': '2020-10-25T14:00:20.549Z',
#                                 'url': 'https://artifacts.elastic.co/downloads/kibana/kibana-6.3.2-linux-x86_64.tar.gz',
#                                 'utc_time': '2020-10-25T14:00:20.549Z'},
#                     '_type': '_doc'},
#                    {'_id': 'ro36jnUBztxdYHj6w_99',
#                     '_index': 'kibana_sample_data_logs',
#                     '_score': 1.9655675,
#                     '_source': {'agent': 'Mozilla/5.0 (X11; Linux x86_64; '
#                                          'rv:6.0a1) Gecko/20110421 '
#                                          'Firefox/6.0a1',
#                                 'bytes': 2647,
#                                 'clientip': '37.50.224.168',
#                                 'extension': 'gz',
#                                 'geo': {'coordinates': {'lat': 41.32702778,
#                                                         'lon': -94.44572222},
#                                         'dest': 'BI',
#                                         'src': 'KH',
#                                         'srcdest': 'KH:BI'},
#                                 'host': 'artifacts.elastic.co',
#                                 'index': 'kibana_sample_data_logs',
#                                 'ip': '37.50.224.168',
#                                 'machine': {'os': 'osx', 'ram': 2147483648},
#                                 'memory': None,
#                                 'message': '37.50.224.168 - - '
#                                            '[2018-07-22T13:38:26.185Z] "GET '
#                                            '/kibana/kibana-6.3.2-linux-x86_64.tar.gz '
#                                            'HTTP/1.1" 200 2647 "-" '
#                                            '"Mozilla/5.0 (X11; Linux x86_64; '
#                                            'rv:6.0a1) Gecko/20110421 '
#                                            'Firefox/6.0a1"',
#                                 'phpmemory': None,
#                                 'referer': 'http://nytimes.com/success/pham-tuan',
#                                 'request': '/kibana/kibana-6.3.2-linux-x86_64.tar.gz',
#                                 'response': 200,
#                                 'tags': ['success', 'login'],
#                                 'timestamp': '2020-10-25T13:38:26.185Z',
#                                 'url': 'https://artifacts.elastic.co/downloads/kibana/kibana-6.3.2-linux-x86_64.tar.gz',
#                                 'utc_time': '2020-10-25T13:38:26.185Z'},
#                     '_type': '_doc'},
#                    {'_id': 'x436jnUBztxdYHj6w_99',
#                     '_index': 'kibana_sample_data_logs',
#                     '_score': 1.9655675,
#                     '_source': {'agent': 'Mozilla/5.0 (X11; Linux x86_64; '
#                                          'rv:6.0a1) Gecko/20110421 '
#                                          'Firefox/6.0a1',
#                                 'bytes': 9052,
#                                 'clientip': '242.180.65.1',
#                                 'extension': 'gz',
#                                 'geo': {'coordinates': {'lat': 30.21208333,
#                                                         'lon': -85.68280556},
#                                         'dest': 'CN',
#                                         'src': 'CN',
#                                         'srcdest': 'CN:CN'},
#                                 'host': 'artifacts.elastic.co',
#                                 'index': 'kibana_sample_data_logs',
#                                 'ip': '242.180.65.1',
#                                 'machine': {'os': 'win xp', 'ram': 13958643712},
#                                 'memory': None,
#                                 'message': '242.180.65.1 - - '
#                                            '[2018-07-22T11:51:09.982Z] "GET '
#                                            '/kibana/kibana-6.3.2-linux-x86_64.tar.gz '
#                                            'HTTP/1.1" 200 9052 "-" '
#                                            '"Mozilla/5.0 (X11; Linux x86_64; '
#                                            'rv:6.0a1) Gecko/20110421 '
#                                            'Firefox/6.0a1"',
#                                 'phpmemory': None,
#                                 'referer': 'http://facebook.com/success/yuri-gagarin',
#                                 'request': '/kibana/kibana-6.3.2-linux-x86_64.tar.gz',
#                                 'response': 200,
#                                 'tags': ['success', 'info'],
#                                 'timestamp': '2020-10-25T11:51:09.982Z',
#                                 'url': 'https://artifacts.elastic.co/downloads/kibana/kibana-6.3.2-linux-x86_64.tar.gz',
#                                 'utc_time': '2020-10-25T11:51:09.982Z'},
#                     '_type': '_doc'},
#                    {'_id': 'zo36jnUBztxdYHj6w_99',
#                     '_index': 'kibana_sample_data_logs',
#                     '_score': 1.9655675,
#                     '_source': {'agent': 'Mozilla/5.0 (X11; Linux i686) '
#                                          'AppleWebKit/534.24 (KHTML, like '
#                                          'Gecko) Chrome/11.0.696.50 '
#                                          'Safari/534.24',
#                                 'bytes': 3378,
#                                 'clientip': '216.93.115.143',
#                                 'extension': 'gz',
#                                 'geo': {'coordinates': {'lat': 35.63523944,
#                                                         'lon': -77.38532028},
#                                         'dest': 'IN',
#                                         'src': 'UG',
#                                         'srcdest': 'UG:IN'},
#                                 'host': 'artifacts.elastic.co',
#                                 'index': 'kibana_sample_data_logs',
#                                 'ip': '216.93.115.143',
#                                 'machine': {'os': 'win xp', 'ram': 8589934592},
#                                 'memory': None,
#                                 'message': '216.93.115.143 - - '
#                                            '[2018-07-22T13:34:18.896Z] "GET '
#                                            '/kibana/kibana-6.3.2-linux-x86_64.tar.gz '
#                                            'HTTP/1.1" 200 3378 "-" '
#                                            '"Mozilla/5.0 (X11; Linux i686) '
#                                            'AppleWebKit/534.24 (KHTML, like '
#                                            'Gecko) Chrome/11.0.696.50 '
#                                            'Safari/534.24"',
#                                 'phpmemory': None,
#                                 'referer': 'http://www.elastic-elastic-elastic.com/success/jerry-linenger',
#                                 'request': '/kibana/kibana-6.3.2-linux-x86_64.tar.gz',
#                                 'response': 200,
#                                 'tags': ['success', 'info'],
#                                 'timestamp': '2020-10-25T13:34:18.896Z',
#                                 'url': 'https://artifacts.elastic.co/downloads/kibana/kibana-6.3.2-linux-x86_64.tar.gz',
#                                 'utc_time': '2020-10-25T13:34:18.896Z'},
#                     '_type': '_doc'},
#                    {'_id': '2o36jnUBztxdYHj6w_99',
#                     '_index': 'kibana_sample_data_logs',
#                     '_score': 1.9655675,
#                     '_source': {'agent': 'Mozilla/5.0 (X11; Linux x86_64; '
#                                          'rv:6.0a1) Gecko/20110421 '
#                                          'Firefox/6.0a1',
#                                 'bytes': 3841,
#                                 'clientip': '202.165.185.121',
#                                 'extension': 'gz',
#                                 'geo': {'coordinates': {'lat': 42.55145611,
#                                                         'lon': -94.19255111},
#                                         'dest': 'SY',
#                                         'src': 'TN',
#                                         'srcdest': 'TN:SY'},
#                                 'host': 'artifacts.elastic.co',
#                                 'index': 'kibana_sample_data_logs',
#                                 'ip': '202.165.185.121',
#                                 'machine': {'os': 'win xp', 'ram': 18253611008},
#                                 'memory': None,
#                                 'message': '202.165.185.121 - - '
#                                            '[2018-07-22T10:29:25.191Z] "GET '
#                                            '/kibana/kibana-6.3.2-linux-x86_64.tar.gz '
#                                            'HTTP/1.1" 200 3841 "-" '
#                                            '"Mozilla/5.0 (X11; Linux x86_64; '
#                                            'rv:6.0a1) Gecko/20110421 '
#                                            'Firefox/6.0a1"',
#                                 'phpmemory': None,
#                                 'referer': 'http://nytimes.com/success/satoshi-furukawa',
#                                 'request': '/kibana/kibana-6.3.2-linux-x86_64.tar.gz',
#                                 'response': 200,
#                                 'tags': ['success', 'login'],
#                                 'timestamp': '2020-10-25T10:29:25.191Z',
#                                 'url': 'https://artifacts.elastic.co/downloads/kibana/kibana-6.3.2-linux-x86_64.tar.gz',
#                                 'utc_time': '2020-10-25T10:29:25.191Z'},
#                     '_type': '_doc'},
#                    {'_id': '3I36jnUBztxdYHj6w_99',
#                     '_index': 'kibana_sample_data_logs',
#                     '_score': 1.9655675,
#                     '_source': {'agent': 'Mozilla/5.0 (X11; Linux i686) '
#                                          'AppleWebKit/534.24 (KHTML, like '
#                                          'Gecko) Chrome/11.0.696.50 '
#                                          'Safari/534.24',
#                                 'bytes': 0,
#                                 'clientip': '226.121.236.73',
#                                 'extension': 'gz',
#                                 'geo': {'coordinates': {'lat': 37.04420944,
#                                                         'lon': -100.9598611},
#                                         'dest': 'MM',
#                                         'src': 'CN',
#                                         'srcdest': 'CN:MM'},
#                                 'host': 'artifacts.elastic.co',
#                                 'index': 'kibana_sample_data_logs',
#                                 'ip': '226.121.236.73',
#                                 'machine': {'os': 'ios', 'ram': 17179869184},
#                                 'memory': None,
#                                 'message': '226.121.236.73 - - '
#                                            '[2018-07-22T08:27:47.775Z] "GET '
#                                            '/kibana/kibana-6.3.2-linux-x86_64.tar.gz '
#                                            'HTTP/1.1" 503 0 "-" "Mozilla/5.0 '
#                                            '(X11; Linux i686) '
#                                            'AppleWebKit/534.24 (KHTML, like '
#                                            'Gecko) Chrome/11.0.696.50 '
#                                            'Safari/534.24"',
#                                 'phpmemory': None,
#                                 'referer': 'http://facebook.com/success/susan-still-kilrain',
#                                 'request': '/kibana/kibana-6.3.2-linux-x86_64.tar.gz',
#                                 'response': 503,
#                                 'tags': ['success', 'info'],
#                                 'timestamp': '2020-10-25T08:27:47.775Z',
#                                 'url': 'https://artifacts.elastic.co/downloads/kibana/kibana-6.3.2-linux-x86_64.tar.gz',
#                                 'utc_time': '2020-10-25T08:27:47.775Z'},
#                     '_type': '_doc'},
#                    {'_id': 'DI76jnUBztxdYHj6wwB-',
#                     '_index': 'kibana_sample_data_logs',
#                     '_score': 1.9655675,
#                     '_source': {'agent': 'Mozilla/5.0 (X11; Linux x86_64; '
#                                          'rv:6.0a1) Gecko/20110421 '
#                                          'Firefox/6.0a1',
#                                 'bytes': 5073,
#                                 'clientip': '79.60.66.243',
#                                 'extension': 'gz',
#                                 'geo': {'coordinates': {'lat': 35.27175278,
#                                                         'lon': -91.27040417},
#                                         'dest': 'PK',
#                                         'src': 'CN',
#                                         'srcdest': 'CN:PK'},
#                                 'host': 'artifacts.elastic.co',
#                                 'index': 'kibana_sample_data_logs',
#                                 'ip': '79.60.66.243',
#                                 'machine': {'os': 'osx', 'ram': 20401094656},
#                                 'memory': None,
#                                 'message': '79.60.66.243 - - '
#                                            '[2018-07-22T16:13:50.313Z] "GET '
#                                            '/kibana/kibana-6.3.2-linux-x86_64.tar.gz '
#                                            'HTTP/1.1" 200 5073 "-" '
#                                            '"Mozilla/5.0 (X11; Linux x86_64; '
#                                            'rv:6.0a1) Gecko/20110421 '
#                                            'Firefox/6.0a1"',
#                                 'phpmemory': None,
#                                 'referer': 'http://facebook.com/success/franklin-chang-diaz',
#                                 'request': '/kibana/kibana-6.3.2-linux-x86_64.tar.gz',
#                                 'response': 200,
#                                 'tags': ['success', 'login'],
#                                 'timestamp': '2020-10-25T16:13:50.313Z',
#                                 'url': 'https://artifacts.elastic.co/downloads/kibana/kibana-6.3.2-linux-x86_64.tar.gz',
#                                 'utc_time': '2020-10-25T16:13:50.313Z'},
#                     '_type': '_doc'}],
#           'max_score': 1.9655675,
#           'total': {'relation': 'gte', 'value': 10000}},
#  'timed_out': False,
#  'took': 629}

# %% [markdown]
# ### Specific fields

# %%
# Query records - specific fields
# url = es_base_url + "_search?q=job_description:linux"
url = es_base_url + "accounts/person/_search?q=job_description:linux"

response = requests.request("GET", url, data="")
response = json.loads(response.text)

pprint(response)
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [{'_id': '2',
#                     '_index': 'accounts',
#                     '_score': 0.9066488,
#                     '_source': {'job_description': 'Linux specialist',
#                                 'lastname': 'Smith',
#                                 'name': 'John'},
#                     '_type': 'person'}],
#           'max_score': 0.9066488,
#           'total': {'relation': 'eq', 'value': 1}},
#  'timed_out': False,
#  'took': 21}
